# %%
import json
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
filters = ['Sub40x40', "2022-05-06" ]

# %%
base_dir = "evaluation_results"
result_jsons = [
    os.path.join(base_dir, f) for f in os.listdir(base_dir) if 
    f.endswith('.json') and all(pattern in f for pattern in filters)
]
result_jsons
# Out:
# ['evaluation_results/2022-05-06_18-12-06-Sub40x40-expert-iters500.json',
#  'evaluation_results/2022-05-06_18-10-59-Sub40x40-naive-iters500.json']

# %%
results = {
    fname.split('-')[-2]: {"rewards": json.load(open(fname, 'r'))["rewards"]} for fname in result_jsons
}

# %%
algo_to_res = {
    fname: {
        'mean': np.mean(result['rewards']),
        'std': np.std(result['rewards']),
        'median': np.median(result['rewards']),
    }
    for fname, result in results.items()
}
algo_to_res
# Out:
# {'expert': {'mean': -10.824537500000002,
#   'std': 29.954181305399064,
#   'median': -0.1},
#  'naive': {'mean': -36.49722500000001,
#   'std': 58.26172633673735,
#   'median': -0.29374999999999996}}

# %%
all_rewards = [
    res['rewards'] for algo, res in results.items() if algo != "random"
]
labels = [a for a in results.keys() if a != "random"]

# %%
rewards = {k: r['rewards'] for k, r in results.items() if k not in {"maskable5m", "random"}}
zipped = list(zip(rewards.values()))

# %%
y = list(rewards.values())

# %%
print(tuple(rewards.keys()))

winners = []

for idx, v in enumerate(zip(*y)):
    v = tuple(round(z, 2) for z in v)
    v_np = np.array(v)
    winner = np.argmax(v_np)
    winner = tuple(rewards.keys())[winner]
#     if (np.abs(v_np[0] - v_np[1]) >= 50 or np.abs(v_np[2] - v_np[1]) >= 50) and winner == "maskable":
    if winner == "expert":
#     if winner == "maskable":
        print(idx, v, winner)
    winners.append(winner)
# Out:
# ('expert', 'naive')
# 0 (-0.07, -0.07) expert
# 2 (-0.04, -0.09) expert
# 3 (-0.33, -95.14) expert
# 4 (-77.61, -89.8) expert
# 5 (-0.11, -48.59) expert
# 6 (-0.17, -153.96) expert
# 7 (-0.04, -0.06) expert
# 8 (-0.04, -0.05) expert
# 9 (-0.83, -4.56) expert
# 10 (-0.01, -0.01) expert
# 12 (-5.83, -58.86) expert
# 13 (-0.06, -0.09) expert
# 14 (-0.06, -0.08) expert
# 15 (-0.2, -21.76) expert
# 16 (-0.06, -0.09) expert
# 17 (-0.06, -0.08) expert
# 18 (-59.28, -64.95) expert
# 19 (-0.04, -0.04) expert
# 20 (-7.67, -116.46) expert
# 21 (-1.51, -118.43) expert
# 22 (-0.01, -0.01) expert
# 23 (-0.02, -0.02) expert
# 24 (-97.62, -103.41) expert
# 25 (-32.59, -54.77) expert
# 26 (-0.04, -0.06) expert
# 27 (-0.06, -0.08) expert
# 28 (-0.01, -0.01) expert
# 29 (-0.04, -0.04) expert
# 30 (-0.06, -0.09) expert
# 31 (-1.28, -101.33) expert
# 33 (-0.32, -0.32) expert
# 34 (-28.68, -48.19) expert
# 35 (-0.04, -1.08) expert
# 36 (-0.32, -0.44) expert
# 37 (-0.01, -0.01) expert
# 38 (-0.04, -0.04) expert
# 39 (-0.32, -0.39) expert
# 40 (-3.81, -162.04) expert
# 41 (-6.11, -50.18) expert
# 42 (-0.06, -0.09) expert
# 44 (-0.17, -20.82) expert
# 46 (-6.89, -24.19) expert
# 47 (-0.07, -0.07) expert
# 48 (-30.51, -157.43) expert
# 49 (-0.02, -0.03) expert
# 50 (-0.06, -0.09) expert
# 51 (-9.54, -151.99) expert
# 52 (-1.34, -6.44) expert
# 53 (-4.67, -24.71) expert
# 54 (-0.04, -0.04) expert
# 55 (-0.36, -0.66) expert
# 56 (-0.8, -58.59) expert
# 58 (-0.04, -94.55) expert
# 60 (-0.12, -0.12) expert
# 62 (-0.07, -0.07) expert
# 63 (-3.21, -8.43) expert
# 64 (-0.01, -0.01) expert
# 65 (-50.79, -97.71) expert
# 66 (-1.73, -48.33) expert
# 67 (-0.02, -0.02) expert
# 68 (-0.01, -0.01) expert
# 69 (-79.56, -88.41) expert
# 70 (-0.04, -0.04) expert
# 71 (-35.44, -47.93) expert
# 72 (-0.06, -0.06) expert
# 73 (-0.04, -0.05) expert
# 75 (-42.47, -56.21) expert
# 76 (-0.06, -31.74) expert
# 77 (-17.46, -98.02) expert
# 78 (-0.07, -0.07) expert
# 79 (-0.07, -0.07) expert
# 81 (-14.19, -225.62) expert
# 82 (-0.06, -0.06) expert
# 83 (-12.71, -31.08) expert
# 84 (-0.01, -0.01) expert
# 85 (-193.38, -229.38) expert
# 86 (-0.04, -0.04) expert
# 88 (-10.64, -112.69) expert
# 90 (-0.04, -0.05) expert
# 91 (-0.06, -0.11) expert
# 92 (-3.26, -29.64) expert
# 93 (-41.52, -97.54) expert
# 94 (-0.12, -0.19) expert
# 95 (-0.06, -0.09) expert
# 96 (-4.01, -19.6) expert
# 97 (-0.07, -0.07) expert
# 98 (-0.04, -0.05) expert
# 99 (-0.02, -0.02) expert
# 100 (-0.04, -0.06) expert
# 101 (-0.04, -0.05) expert
# 102 (-22.83, -56.68) expert
# 103 (-0.06, -0.12) expert
# 104 (-11.87, -89.87) expert
# 106 (-0.2, -0.37) expert
# 107 (-0.02, -0.02) expert
# 108 (-0.09, -0.12) expert
# 109 (-0.06, -0.09) expert
# 110 (-0.02, -0.02) expert
# 111 (-23.33, -229.67) expert
# 112 (-0.06, -0.06) expert
# 113 (-0.02, -0.03) expert
# 114 (-0.06, -0.26) expert
# 115 (-6.71, -170.56) expert
# 116 (-0.06, -0.08) expert
# 117 (-43.88, -53.31) expert
# 118 (-49.45, -85.94) expert
# 119 (-0.01, -0.01) expert
# 120 (-0.07, -0.07) expert
# 121 (-2.11, -8.57) expert
# 122 (-18.51, -108.99) expert
# 123 (-0.06, -0.74) expert
# 124 (-0.06, -0.09) expert
# 125 (-2.77, -3.29) expert
# 126 (-0.06, -0.06) expert
# 127 (-0.26, -63.49) expert
# 128 (-0.16, -0.18) expert
# 129 (-0.07, -0.07) expert
# 131 (-0.02, -0.03) expert
# 132 (-16.46, -35.23) expert
# 133 (-0.04, -0.05) expert
# 134 (-0.94, -172.01) expert
# 135 (-0.06, -0.08) expert
# 136 (-6.49, -35.58) expert
# 137 (-0.07, -0.07) expert
# 138 (-0.07, -117.16) expert
# 139 (-0.02, -0.02) expert
# 140 (-4.44, -16.54) expert
# 141 (-0.06, -0.09) expert
# 144 (-3.91, -64.97) expert
# 145 (-0.01, -0.01) expert
# 146 (-9.36, -125.17) expert
# 147 (-0.57, -0.78) expert
# 149 (-0.01, -0.01) expert
# 150 (-0.02, -0.02) expert
# 151 (-0.07, -0.15) expert
# 152 (-54.32, -59.91) expert
# 153 (-1.63, -74.24) expert
# 154 (-0.04, -0.06) expert
# 157 (-0.04, -0.06) expert
# 158 (-0.01, -0.01) expert
# 159 (-0.06, -0.06) expert
# 160 (-0.34, -111.14) expert
# 161 (-0.04, -0.05) expert
# 162 (-0.02, -0.02) expert
# 163 (-0.07, -0.07) expert
# 164 (-0.06, -0.08) expert
# 165 (-0.04, -0.05) expert
# 166 (-214.95, -274.68) expert
# 167 (-0.04, -0.04) expert
# 169 (-25.19, -119.87) expert
# 171 (-3.92, -103.48) expert
# 172 (-0.06, -0.06) expert
# 173 (-30.67, -88.14) expert
# 174 (-0.01, -0.01) expert
# 175 (-250.64, -258.35) expert
# 176 (-0.06, -0.09) expert
# 177 (-30.84, -77.25) expert
# 178 (-1.02, -131.72) expert
# 179 (-0.06, -46.34) expert
# 180 (-0.22, -67.45) expert
# 181 (-0.01, -0.01) expert
# 182 (-2.45, -4.08) expert
# 183 (-27.28, -80.21) expert
# 184 (-0.02, -0.02) expert
# 185 (-0.02, -0.03) expert
# 186 (-0.04, -0.05) expert
# 187 (-0.04, -0.05) expert
# 189 (-0.06, -0.09) expert
# 190 (-4.1, -93.05) expert
# 191 (-0.02, -0.02) expert
# 192 (-2.37, -135.59) expert
# 193 (-7.31, -124.24) expert
# 194 (-3.13, -141.31) expert
# 195 (-0.07, -0.07) expert
# 196 (-0.01, -0.01) expert
# 197 (-0.02, -0.02) expert
# 198 (-3.64, -103.21) expert
# 199 (-0.06, -0.09) expert
# 200 (-0.06, -0.08) expert
# 201 (-11.27, -173.13) expert
# 202 (-1.09, -117.94) expert
# 203 (-18.18, -91.77) expert
# 204 (-0.04, -0.04) expert
# 205 (-1.14, -7.96) expert
# 206 (-0.02, -0.02) expert
# 207 (-0.07, -0.07) expert
# 208 (-0.06, -0.09) expert
# 209 (-0.04, -0.07) expert
# 210 (-2.31, -230.09) expert
# 211 (-0.06, -0.07) expert
# 212 (-0.06, -0.09) expert
# 213 (-0.32, -0.44) expert
# 214 (-0.06, -0.09) expert
# 215 (-0.72, -0.85) expert
# 216 (-20.3, -24.89) expert
# 218 (-0.01, -0.01) expert
# 219 (-0.06, -0.09) expert
# 220 (-27.51, -243.76) expert
# 221 (-0.01, -0.01) expert
# 222 (-5.58, -78.58) expert
# 223 (-0.04, -0.05) expert
# 224 (-0.53, -23.93) expert
# 225 (-109.81, -169.07) expert
# 226 (-0.02, -0.03) expert
# 227 (-0.54, -1.21) expert
# 228 (-0.35, -33.96) expert
# 229 (-0.02, -0.02) expert
# 230 (-0.04, -0.07) expert
# 231 (-0.02, -0.02) expert
# 232 (-0.06, -0.08) expert
# 233 (-0.01, -0.01) expert
# 234 (-12.03, -86.34) expert
# 235 (-0.24, -122.3) expert
# 237 (-0.04, -0.04) expert
# 238 (-11.41, -173.09) expert
# 240 (-2.36, -86.28) expert
# 241 (-0.07, -0.07) expert
# 242 (-5.97, -20.61) expert
# 243 (-0.2, -0.37) expert
# 245 (-0.32, -0.44) expert
# 246 (-0.06, -0.09) expert
# 248 (-13.91, -122.69) expert
# 249 (-1.25, -2.73) expert
# 250 (-214.45, -229.32) expert
# 251 (-0.06, -0.09) expert
# 252 (-22.05, -184.24) expert
# 253 (-0.01, -0.01) expert
# 254 (-11.31, -27.73) expert
# 255 (-0.06, -0.29) expert
# 256 (-0.02, -0.02) expert
# 257 (-0.02, -0.02) expert
# 258 (-0.04, -0.04) expert
# 259 (-3.22, -32.09) expert
# 260 (-44.61, -95.46) expert
# 261 (-0.02, -0.02) expert
# 263 (-0.02, -0.02) expert
# 264 (-0.06, -0.09) expert
# 265 (-0.02, -0.03) expert
# 266 (-0.07, -0.09) expert
# 267 (-0.06, -0.09) expert
# 268 (-0.06, -0.08) expert
# 269 (-0.06, -0.08) expert
# 270 (-0.01, -0.01) expert
# 271 (-0.04, -0.05) expert
# 272 (-45.15, -59.01) expert
# 273 (-0.06, -0.07) expert
# 274 (-0.06, -0.09) expert
# 275 (-15.53, -122.46) expert
# 278 (-0.07, -0.07) expert
# 279 (-0.04, -58.47) expert
# 280 (-0.01, -0.01) expert
# 281 (-9.27, -85.99) expert
# 283 (-0.06, -96.64) expert
# 284 (-54.61, -85.92) expert
# 285 (-4.39, -31.79) expert
# 286 (-0.04, -0.04) expert
# 288 (-0.06, -0.09) expert
# 290 (-0.09, -0.16) expert
# 291 (-0.02, -0.02) expert
# 292 (-0.02, -0.02) expert
# 293 (-0.06, -0.29) expert
# 294 (-208.44, -228.33) expert
# 295 (-0.2, -184.96) expert
# 296 (-0.04, -0.04) expert
# 298 (-0.86, -109.07) expert
# 299 (-0.83, -5.42) expert
# 300 (-0.21, -87.81) expert
# 301 (-0.07, -0.07) expert
# 302 (-0.02, -0.02) expert
# 303 (-1.67, -51.24) expert
# 305 (-0.06, -0.08) expert
# 306 (-0.06, -95.93) expert
# 307 (-1.71, -136.02) expert
# 308 (-0.04, -0.07) expert
# 309 (-0.06, -0.09) expert
# 310 (-2.12, -27.15) expert
# 311 (-0.06, -0.11) expert
# 312 (-0.02, -0.02) expert
# 313 (-0.06, -59.59) expert
# 314 (-0.02, -0.02) expert
# 315 (-0.01, -0.01) expert
# 316 (-0.01, -0.01) expert
# 317 (-0.04, -0.04) expert
# 318 (-3.02, -3.84) expert
# 319 (-0.2, -0.3) expert
# 320 (-36.42, -115.1) expert
# 321 (-32.31, -49.32) expert
# 323 (-0.04, -0.06) expert
# 324 (-0.09, -0.09) expert
# 325 (-53.13, -61.44) expert
# 326 (-0.32, -0.41) expert
# 327 (-0.06, -0.09) expert
# 328 (-7.1, -67.54) expert
# 330 (-0.01, -0.01) expert
# 331 (-109.44, -116.61) expert
# 332 (-4.67, -31.3) expert
# 333 (-16.29, -35.38) expert
# 334 (-1.91, -10.47) expert
# 335 (-50.64, -112.12) expert
# 336 (-1.72, -3.1) expert
# 337 (-10.55, -41.71) expert
# 338 (-54.4, -64.04) expert
# 339 (-17.62, -210.74) expert
# 340 (-0.19, -0.2) expert
# 341 (-0.02, -0.02) expert
# 342 (-0.05, -0.07) expert
# 343 (-0.06, -0.09) expert
# 344 (-0.02, -0.02) expert
# 345 (-2.5, -7.67) expert
# 346 (-0.01, -0.01) expert
# 347 (-6.4, -91.39) expert
# 348 (-0.04, -0.06) expert
# 349 (-0.06, -0.09) expert
# 350 (-0.04, -3.52) expert
# 351 (-37.57, -87.52) expert
# 352 (-0.27, -72.29) expert
# 353 (-0.01, -0.01) expert
# 354 (-7.99, -46.86) expert
# 355 (-2.49, -20.74) expert
# 356 (-9.56, -77.28) expert
# 357 (-0.49, -51.17) expert
# 358 (-0.02, -0.03) expert
# 362 (-10.64, -240.12) expert
# 365 (-0.04, -0.07) expert
# 366 (-4.21, -106.29) expert
# 367 (-0.06, -0.08) expert
# 368 (-0.06, -0.26) expert
# 369 (-71.4, -84.87) expert
# 370 (-0.06, -0.09) expert
# 371 (-0.01, -0.01) expert
# 372 (-0.04, -0.07) expert
# 373 (-0.26, -88.93) expert
# 374 (-0.04, -0.07) expert
# 375 (-0.32, -0.35) expert
# 376 (-0.9, -80.36) expert
# 377 (-0.06, -86.72) expert
# 378 (-15.17, -211.44) expert
# 379 (-0.07, -0.07) expert
# 380 (-1.82, -10.47) expert
# 381 (-18.47, -112.92) expert
# 382 (-0.22, -94.05) expert
# 383 (-0.06, -0.09) expert
# 384 (-0.07, -0.07) expert
# 387 (-13.11, -30.94) expert
# 389 (-0.02, -0.02) expert
# 390 (-0.02, -0.02) expert
# 391 (-0.02, -0.02) expert
# 392 (-5.41, -105.82) expert
# 393 (-17.37, -90.21) expert
# 394 (-6.69, -184.61) expert
# 395 (-43.84, -58.93) expert
# 398 (-0.04, -0.04) expert
# 399 (-0.06, -0.09) expert
# 401 (-0.07, -0.07) expert
# 402 (-8.36, -253.89) expert
# 403 (-4.6, -26.44) expert
# 404 (-5.33, -24.5) expert
# 405 (-0.04, -0.05) expert
# 406 (-0.02, -0.02) expert
# 408 (-2.98, -265.19) expert
# 409 (-0.07, -0.07) expert
# 410 (-0.02, -0.02) expert
# 412 (-13.84, -66.16) expert
# 413 (-0.01, -0.01) expert
# 414 (-1.22, -100.56) expert
# 415 (-0.01, -0.01) expert
# 416 (-0.2, -0.38) expert
# 417 (-31.04, -53.59) expert
# 418 (-0.02, -0.02) expert
# 419 (-18.03, -136.48) expert
# 420 (-0.02, -0.02) expert
# 421 (-1.73, -18.61) expert
# 422 (-0.07, -0.07) expert
# 423 (-6.56, -22.85) expert
# 425 (-0.01, -0.01) expert
# 426 (-0.02, -0.02) expert
# 427 (-0.06, -0.08) expert
# 428 (-0.02, -0.02) expert
# 430 (-0.06, -0.06) expert
# 431 (-0.06, -0.09) expert
# 432 (-0.22, -78.91) expert
# 433 (-0.22, -36.44) expert
# 434 (-31.18, -55.06) expert
# 435 (-0.22, -31.37) expert
# 436 (-0.06, -0.09) expert
# 437 (-0.07, -0.07) expert
# 438 (-0.04, -0.05) expert
# 439 (-0.01, -0.01) expert
# 440 (-0.02, -0.02) expert
# 441 (-0.04, -0.04) expert
# 442 (-5.77, -113.05) expert
# 443 (-6.62, -20.26) expert
# 444 (-0.02, -0.02) expert
# 445 (-9.15, -27.83) expert
# 446 (-42.29, -57.81) expert
# 447 (-0.07, -0.07) expert
# 448 (-0.04, -0.04) expert
# 449 (-0.06, -0.09) expert
# 450 (-0.02, -0.02) expert
# 451 (-0.01, -0.01) expert
# 452 (-0.04, -0.05) expert
# 453 (-0.06, -97.22) expert
# 454 (-0.04, -0.51) expert
# 456 (-0.09, -0.14) expert
# 457 (-0.01, -0.01) expert
# 458 (-0.98, -4.26) expert
# 459 (-28.52, -244.35) expert
# 460 (-0.01, -0.01) expert
# 461 (-4.34, -7.48) expert
# 462 (-13.63, -38.63) expert
# 463 (-0.06, -0.09) expert
# 464 (-0.74, -152.24) expert
# 465 (-0.73, -6.21) expert
# 466 (-0.06, -0.09) expert
# 467 (-10.28, -176.44) expert
# 468 (-0.02, -0.02) expert
# 469 (-0.07, -0.07) expert
# 471 (-3.04, -141.49) expert
# 472 (-12.41, -27.66) expert
# 473 (-0.06, -28.7) expert
# 474 (-0.06, -0.08) expert
# 475 (-5.62, -11.71) expert
# 476 (-0.02, -0.02) expert
# 477 (-41.99, -53.84) expert
# 478 (-2.74, -139.91) expert
# 479 (-0.06, -0.33) expert
# 480 (-0.02, -0.03) expert
# 481 (-0.2, -160.91) expert
# 482 (-7.28, -107.98) expert
# 483 (-0.07, -0.07) expert
# 484 (-0.06, -0.06) expert
# 486 (-8.11, -22.35) expert
# 487 (-1.27, -86.51) expert
# 488 (-0.04, -0.04) expert
# 489 (-0.06, -0.06) expert
# 490 (-0.02, -0.02) expert
# 491 (-3.03, -141.7) expert
# 492 (-0.01, -0.01) expert
# 493 (-1.38, -81.16) expert
# 495 (-1.11, -91.47) expert
# 497 (-0.01, -0.01) expert
# 498 (-0.14, -149.61) expert
# 499 (-0.06, -0.09) expert
